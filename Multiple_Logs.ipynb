# %% [markdown]
# # Plot a Striplog from a StratLogger CSV
#
# Uses format exported by "StratLogger," an Android app for quick-logging stratigraphic sections that was developed at Colorado School of Mines
# https://github.com/jcliang001/Stratlogger

# %%
#%matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

import striplog
from striplog import Lexicon, Decor, Component, Legend, Interval, Striplog
print('FYI, the striplog version you have is',striplog.__version__)
# Out:
# FYI, the striplog version you have is 0.8.3

# %% [markdown]
# ## Make legend
#
# Most of the stuff in the dicts you made were about **display** — so they are going to make `Decor` objects. A collection of `Decor`s makes a `Legend`. A `Legend` determines how a striplog is displayed.
#
# First I'll make the components, since those are easy. I'll move `'train'` into there too, since it is to do with the rocks, not the display. If it seems weird having `'train'` in the `Component` (which is really supposed to be about direct descriptions of the rock, but the idea is that it's always the same for all specimens of that rock so it does fit here) then you could put it in `data` instead.

# %%
# define your abbreviations here, this is what the CSV will read in

facies = {
    'sand': Component({'lithology': 'sandstone', 'train':'y'}),
    'mud': Component({'lithology': 'mudstone', 'train':'y'}),
    'other': Component({'lithology': 'calcilutite', 'train': 'n'}),
}

# %%
facies.keys()
# Out:
# dict_keys(['sand', 'mud', 'other'])

# %%
# pick how your facies will look in the log, see striplog for specfics

# NEED TO FIGURE OUT HOW TO PLOT EDGECOLORS!!!!!!!!!!
########
########
#######

sandstone = Decor({
    'component': facies['sand'],
    'colour': 'yellow',
    'hatch': 'none',
    'width': '3',
    'edgecolor': 'k',
})

mudstone = Decor({
    'component': facies['mud'],
    'colour': 'darkgray',
    'hatch': 'none',
    'width': '2',
    'edgecolor': 'k',
})

calcilutite = Decor({
    'component': facies['other'],
    'colour': 'blue',
    'hatch': 'none',
    'width': '1',
    'edgecolor': 'k',
})
legend = Legend([sandstone, mudstone, calcilutite])
legend
# Out:
# Legend(Decor({'component': Component({'lithology': 'sandstone', 'train': 'y'}), '_colour': '#ffff00', 'hatch': None, 'width': 3.0, 'edgecolor': 'k'})
# Decor({'component': Component({'lithology': 'mudstone', 'train': 'y'}), '_colour': '#a9a9a9', 'hatch': None, 'width': 2.0, 'edgecolor': 'k'})
# Decor({'component': Component({'lithology': 'calcilutite', 'train': 'n'}), '_colour': '#0000ff', 'hatch': None, 'width': 1.0, 'edgecolor': 'k'}))

# %% [markdown]
# ## Read CSV into striplog

# %%
pathname = '/OneDrive/OneDrive - Colorado School of Mines/THESIS/StratLoggerPlotter/'
LogA = Striplog.from_csv(pathname + 'LogA SL4.csv') # reading in the CSV file
for s in LogA:
    lith = s.data['lithname']
    s.components = [facies[lith]]
    s.bedid = s.data['bedid']
    s.data = {}

LogB = Striplog.from_csv(pathname + 'LogB SL8.csv') # reading in the CSV file
for s in LogB:
    lith = s.data['lithname']
    s.components = [facies[lith]]
    s.bedid = s.data['bedid']
    s.data = {}

LogC = Striplog.from_csv(pathname + 'LogC SL7.csv') # reading in the CSV file
for s in LogC:
    lith = s.data['lithname']
    s.components = [facies[lith]]
    s.bedid = s.data['bedid']
    s.data = {}
    
LogD = Striplog.from_csv(pathname + 'LogD SL1.csv') # reading in the CSV file
for s in LogD:
    lith = s.data['lithname']
    s.components = [facies[lith]]
    s.bedid = s.data['bedid']
    s.data = {}
    
LogE = Striplog.from_csv(pathname + 'LogE SL2.csv') # reading in the CSV file
for s in LogE:
    lith = s.data['lithname']
    s.components = [facies[lith]]
    s.bedid = s.data['bedid']
    s.data = {}
    
LogF = Striplog.from_csv(pathname + 'LogF SL5.csv') # reading in the CSV file
for s in LogF:
    lith = s.data['lithname']
    s.components = [facies[lith]]
    s.bedid = s.data['bedid']
    s.data = {}
    
LogG = Striplog.from_csv(pathname + 'LogG SL6.csv') # reading in the CSV file
for s in LogG:
    lith = s.data['lithname']
    s.components = [facies[lith]]
    s.bedid = s.data['bedid']
    s.data = {}
    
LogH = Striplog.from_csv(pathname + 'LogH SL3.csv') # reading in the CSV file
for s in LogH:
    lith = s.data['lithname']
    s.components = [facies[lith]]
    s.bedid = s.data['bedid']
    s.data = {}

# %%
fig, (ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8) = plt.subplots(1, 8, figsize=(20,200), sharey=True)

#### first log
LogA.plot(legend=legend, return_fig=True, ax=ax1)
# get klugey values for text
x=np.zeros(len(LogA))
x=x.reshape(-1,1)
y=[]
bedid=[]
for s in LogA:
    y.append(s.base.middle)
    bedid.append(s.bedid)
for i in range(len(bedid)):
    ax1.text(x[i],y[i],bedid[i])

#### second log
LogB.plot(legend=legend, return_fig=True, ax=ax2)
# get klugey values for text
x=np.zeros(len(LogB))
x=x.reshape(-1,1)
y=[]
bedid=[]
for s in LogB:
    y.append(s.base.middle)
    bedid.append(s.bedid)
for i in range(len(bedid)):
    ax2.text(x[i],y[i],bedid[i])

#### third log
LogC.plot(legend=legend, return_fig=True, ax=ax3)
# get klugey values for text
x=np.zeros(len(LogC))
x=x.reshape(-1,1)
y=[]
bedid=[]
for s in LogC:
    y.append(s.base.middle)
    bedid.append(s.bedid)
for i in range(len(bedid)):
    ax3.text(x[i],y[i],bedid[i])

#### fourth log
LogD.plot(legend=legend, return_fig=True, ax=ax4)
# get klugey values for text
x=np.zeros(len(LogD))
x=x.reshape(-1,1)
y=[]
bedid=[]
for s in LogD:
    y.append(s.base.middle)
    bedid.append(s.bedid)
for i in range(len(bedid)):
    ax4.text(x[i],y[i],bedid[i])

#### fifth log
LogE.plot(legend=legend, return_fig=True, ax=ax5)
# get klugey values for text
x=np.zeros(len(LogE))
x=x.reshape(-1,1)
y=[]
bedid=[]
for s in LogE:
    y.append(s.base.middle)
    bedid.append(s.bedid)
for i in range(len(bedid)):
    ax5.text(x[i],y[i],bedid[i])

#### sixth log
LogF.plot(legend=legend, return_fig=True, ax=ax6)
# get klugey values for text
x=np.zeros(len(LogF))
x=x.reshape(-1,1)
y=[]
bedid=[]
for s in LogF:
    y.append(s.base.middle)
    bedid.append(s.bedid)
for i in range(len(bedid)):
    ax6.text(x[i],y[i],bedid[i])
        
#### seventh log
LogG.plot(legend=legend, return_fig=True, ax=ax7)
# get klugey values for text
x=np.zeros(len(LogG))
x=x.reshape(-1,1)
y=[]
bedid=[]
for s in LogG:
    y.append(s.base.middle)
    bedid.append(s.bedid)
for i in range(len(bedid)):
    ax7.text(x[i],y[i],bedid[i])

#### eighth log
LogH.plot(legend=legend, return_fig=True, ax=ax8)
# get klugey values for text
x=np.zeros(len(LogH))
x=x.reshape(-1,1)
y=[]
bedid=[]
for s in LogH:
    y.append(s.base.middle)
    bedid.append(s.bedid)
for i in range(len(bedid)):
    ax8.text(x[i],y[i],bedid[i])

# %%
# Save figure
fig.savefig('_export.pdf')

# %% [markdown]
# ## Remove non-training layers

# %%
strip
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-865d6e1ab2d8> in <module>
# ----> 1 strip
#
# NameError: name 'strip' is not defined

# %%
strip_train = Striplog([s for s in strip if s.primary['train'] == 'y'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-a719b31b91bc> in <module>
# ----> 1 strip_train = Striplog([s for s in strip if s.primary['train'] == 'y'])
#
# NameError: name 'strip' is not defined

# %%
strip_train

strip_train.plot(legend)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-85-effe82f2b7e3> in <module>
# ----> 1 strip_train
#       2
#       3 strip_train.plot(legend)
#
# NameError: name 'strip_train' is not defined

# %%
# plottin' & exportin'

fig, (ax0, ax1) = plt.subplots(1, 2, sharey=True)
fig.set_size_inches(7, 11) # Set the figure size

ax0 = strip.plot(legend, ax=ax0)
ax1 = strip_train.plot(legend, ax=ax1)

ax0.set_title('Picks')
ax1.set_title('Training')

ax0.set_ylabel('Depth (m)', size=16)

plt.show()
fig.savefig('Picks_v_training.pdf', dpi=300)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-86-0472f903ad64> in <module>
#       4 fig.set_size_inches(7, 11) # Set the figure size
#       5
# ----> 6 ax0 = strip.plot(legend, ax=ax0)
#       7 ax1 = strip_train.plot(legend, ax=ax1)
#       8
#
# NameError: name 'strip' is not defined

# %%
print(strip.to_csv())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-87-458dbce5aae9> in <module>
# ----> 1 print(strip.to_csv())
#
# NameError: name 'strip' is not defined
